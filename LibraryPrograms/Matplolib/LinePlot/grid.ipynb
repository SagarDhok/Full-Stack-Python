# %%
#Setting the grid 
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.plot(x,y ,ls= "solid",lw=3,c = "red",marker="o",mec ="red",mfc="yellow",ms=10)
plt.grid(axis="x")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.plot(x,y,ls="solid",lw=3,c="red",marker="o",mec="red",mfc="yellow",ms=10)
plt.grid(axis="y")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.plot(x,y,ls="solid",lw=3,c="r",marker="o",mec="red",mfc="yellow",ms=10)
# plt.grid(axis="both")
#*or
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.plot(x,y,ls="solid",lw=3,c="r",marker="o",mec="red",mfc="yellow",ms=10)
plt.grid(axis="both",ls="dotted",c="green")
plt.show()
#!he nay lihaych

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.plot(x,y,ls="solid",lw=3,c="r",marker="o",mec="red",mfc="yellow",ms=10)
plt.grid(axis="both",ls="dotted",c="green")
plt.xlabel("X-axis",fontdict={"family":"arial","color":"blue","size":15})
plt.ylabel("Y-labe",fontdict={"family":"arial","color":"blue","size":15})
plt.title("Line plot",fontdict={"family":"Times New Roman","color":"red","size":25})
plt.show()
#!he nay lihaych

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.xlim(0,6)
plt.ylim(0,6)
plt.xticks([1,2,3,4,5,6])
plt.yticks([1,2,3,4,5,6])
plt.plot(x,y,ls="solid",lw=3,c="r",marker="o",mec="red",mfc="yellow",ms=10)
plt.grid(axis="both",ls="dotted",c="green")
plt.xlabel("X-axis",fontdict={"family":"arial","color":"blue","size":15})
plt.ylabel("Y-axis",fontdict={"family":"arial","color":"blue","size":15})
plt.title("Line plot",fontdict={"family":"Times New Roman","color":"red","size":25})
plt.show()

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.xlim(0,6)
plt.ylim(0,6)
plt.xticks([1,2,3,4,5,6])
plt.yticks([1,2,3,4,5,6])
plt.plot(x,y,ls="solid",lw=3,c="r",marker="o",mec="red",mfc="yellow",ms=10)
plt.plot(x,[3,4,2,1],ls="solid",lw=3,c="hotpink",marker="X",mec="black",mfc="blue",ms=10)
plt.grid(axis="both",ls="dotted",c="green")
plt.xlabel("X-axis",fontdict={"family":"arial","color":"blue","size":15})
plt.ylabel("Y-labe",fontdict={"family":"arial","color":"blue","size":15})
plt.title("Line plot",fontdict={"family":"Times New Roman","color":"red","size":25})
plt.show()
#!he nay lihaych

# %%
import matplotlib.pyplot as plt
x=[2,1,3,4]
y=[2,3,4,1]
plt.xlim(0,6)
plt.ylim(0,6)
plt.xticks([1,2,3,4,5,6])
plt.yticks([1,2,3,4,5,6])
plt.plot(x,y,ls="solid",lw=3,c="r",marker="o",mec="red",mfc="yellow",ms=10)
plt.plot(x,[3,4,2,1],ls="solid",lw=3,c="hotpink",marker="X",mec="black",mfc="blue",ms=10)
plt.grid(axis="both",ls="dashed",c="green")
plt.xlabel("X-axis",fontdict={"family":"arial","color":"blue","size":15})
plt.ylabel("Y-axis",fontdict={"family":"arial","color":"blue","size":15})
plt.title("Line plot",fontdict={"family":"Times New Roman","color":"red","size":25})
plt.legend(labels=["india","Newzland"])
plt.show()
